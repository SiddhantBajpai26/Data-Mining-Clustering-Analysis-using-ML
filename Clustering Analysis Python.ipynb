# %% [markdown]
# # Assignment 2 - Clustering
#
# Some basic code has been provided for you. You will need to make some small edits to complete the tasks in the instructions document.
#
# Feel free to write additional code as needed to support/illuminate your discussion in your report.

# %%
import numpy as np
from numpy import unique  # can also just use np.unique
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# # Task 1
#
# Load in the <code>salary_data.csv</code> dataset which has 50 data points and two dimensions (age, salary).
#
# Randomly generate a dataset with <b>50</b> data points using the <code>generate_random_data</code> method below.
#
# Run kmeans 10 times on each dataset.

# %% [markdown]
# #### Import Salary Dataset

# %%
salary_data = pd.read_csv('data/salary_data.csv')
print(salary_data.shape)
salary_data.head()
# Out:
# (49, 2)
#    age  income
# 0   14    2500
# 1   15    5500
# 2   16    5000
# 3   15    4500
# 4   16    2000

# %%
plt.scatter(salary_data.age, salary_data.income)

# %% [markdown]
# #### 1.1 Generate Random Data

# %%
def generate_random_data(n):
    '''function to generate n random 2D data points stored in an (n, 2) dataframe'''
    return pd.DataFrame({'age':np.random.rand(n), 'income':np.random.rand(n)})

# %% [markdown]
# Every time you run the <code>generate_random_data</code> function you will generate a new dataset so make sure you assign your dataset to a variable and don't write over that variable unless you're finished with it.

# %%
########## EVERY TIME YOU RUN THIS YOU WILL GENERATE NEW DATA ##########

# set n equal to the size of the dataset you want
rand_data = generate_random_data(50)

# %%
plt.scatter(rand_data.age, rand_data.income)

# %% [markdown]
# #### 1.2 Run K-means
# Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#sklearn.cluster.KMeans

# %%
# use this function to run kmeans on your dataframe
def run_kmeans(k, dataset, x_col='', y_col=''):
    # let's make a copy of the dataframe so we can freely add columns
    df = dataset.copy(deep=True) # just for our use case, don't do this as standard

##1.2 Describe your understanding of these three parameters in the run_kmeans function and discuss how they impact the results:
    kmeans = KMeans(n_clusters=k, init='random', n_init=1)
    
    kmeans.fit(dataset)
    cluster_labels = kmeans.fit_predict(dataset)
    df[f'cluster_labels'] = cluster_labels
    plt.scatter(df[x_col], df[y_col], c=kmeans.labels_.astype(float))
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    
    plt.show()
    
    return df

# %%
sal_data_run_1_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_2_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_3_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_4_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_5_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_6_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_7_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_8_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_9_df = run_kmeans(3, salary_data, x_col='age', y_col='income')
sal_data_run_10_df = run_kmeans(3, salary_data, x_col='age', y_col='income')

##centroid
X = np.random.rand(50, 2)
k = 3  # Number of clusters
kmeans = KMeans(n_clusters=k)
kmeans.fit(rand_data)
#kmeans.fit(salary_data)
cluster_labels = kmeans.labels_
centroids = kmeans.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=cluster_labels, cmap='viridis', edgecolors='k', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=200, label='Centroids')  # Plot centroids
plt.legend()
plt.xlabel('age')
plt.ylabel('income')
plt.title('K-means Clustering with Centroids')
plt.show()

#salary_data_runs = [run_kmeans(3, salary_data, x_col='age', y_col='income') for i in range(10)]

# %% [markdown]
# ###K-means of random_data generated with 50 points

# %%
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
rand_runs_1_df = run_kmeans(3, rand_data, x_col='age', y_col='income')
#rand_runs = [run_kmeans(3, rand_data, x_col='age', y_col='income') for i in range(10)]

# %% [markdown]
# ## Kmeans++

# %%
## 1.3 create a new function that runs k-means on your datasets but this time using k-means++
def run_kmeans_plus(k, dataset, x_col='', y_col=''):
    # let's make a copy of the dataframe so we can freely add columns
    df = dataset.copy(deep=True) # just for our use case, don't do this as standard

    kmeans_plus = KMeans(n_clusters=k, init='k-means++', n_init=1)
    kmeans_plus.fit(dataset)
    cluster_labels = kmeans_plus.fit_predict(dataset)
    df[f'cluster_labels'] = cluster_labels
    plt.scatter(df[x_col], df[y_col], c=kmeans_plus.labels_.astype(float))
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    
    plt.show()
    
    return df

# %%
## 1.3 Re-run k-means using k-means++ on the salary dataset.
sal_data_run_plus_1_df = [run_kmeans_plus(3, salary_data, x_col='age', y_col='income') for i in range(10)]

#rand_runs_plus = [run_kmeans_plus(3, rand_data, x_col='age', y_col='income') for i in range(10)]

# %% [markdown]
# ### Elbow Method

# %%
def get_elbow_plot(dataset, x_col='', y_col='', min_k=2, max_k=10):
    
    # for what values of k do we want to run
    k_range = range(min_k, max_k)

    # calculate sum of squared error for each value of k
    sse = [] # initialze empty list

    for k in k_range:
        km = KMeans(n_clusters=k) # set whatever other parameters you want here
        km.fit(dataset)
        sse.append(km.inertia_)

    plt.xlabel('K')
    plt.ylabel('Sum of Squared Error')
    plt.plot(k_range, sse)
    plt.show()

# %%
#get_elbow_plot(salary_data, x_col='age', y_col='income')

# %%
##1.4 create your own dataset of 30 points
rand_data_elbow = generate_random_data(30)

##1.4 generate an elbow plot for that data
get_elbow_plot(rand_data_elbow, x_col='x', y_col='y')

# %% [markdown]
# #### Normalize salary data

# %%
scaler = MinMaxScaler()
scaler.fit(salary_data[['age']])
salary_data['normalized_age'] = scaler.transform(salary_data[['age']])
salary_data.head()
# Out:
#    age  income  normalized_age
# 0   14    2500        0.000000
# 1   15    5500        0.018182
# 2   16    5000        0.036364
# 3   15    4500        0.018182
# 4   16    2000        0.036364

# %%
scaler = MinMaxScaler()
scaler.fit(salary_data[['income']])
salary_data['normalized_income'] = scaler.transform(salary_data[['income']])
salary_data.head()
# Out:
#    age  income  normalized_age  normalized_income
# 0   14    2500        0.000000           0.005556
# 1   15    5500        0.018182           0.038889
# 2   16    5000        0.036364           0.033333
# 3   15    4500        0.018182           0.027778
# 4   16    2000        0.036364           0.000000

# %%
km = KMeans(n_clusters=4) # or whatever number of k you want
cluster_labels = km.fit_predict(salary_data[['normalized_age', 'normalized_income']])
salary_data['normalized_cluster'] = cluster_labels
plt.scatter(salary_data.normalized_age, salary_data.normalized_income, c=km.labels_.astype(float))

# %% [markdown]
# # Task 2
#
# We'll use Sklearn's <code>make_classification</code> method to generate a dataset. See documentation here: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html
#
# We aren't interested in the labels per-se, but it will generate some nicely clustered data for us to try out some algorithms on.

# %% [markdown]
# ### 2.1 Generate a dataset with 3,000 samples (points) using the sklearn.datasets.make_classification method. Run it until you find a dataset you think is interesting to cluster. You can also use multiple datasets.

# %%
# define dataset
data_values, class_labels = make_classification(n_samples=3000, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=2, random_state=None)
# Initialize list to hold sum of squared distances
ssd = []

# Compute sum of squared distances for range of n_clusters
for k in range(1, 11):
    kmeans_model = KMeans(n_clusters=k)
    kmeans_model.fit(data_values)
    ssd.append(kmeans_model.inertia_)

# Plot sum of squared distances against n_clusters
plt.plot(range(1, 11), ssd, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared distances')
plt.show()

# %%
# create scatter plot for samples from each class
for class_value in range(len(unique(class_labels))):
    # get row indexes for samples with this class
    row_ix = np.where(class_labels == class_value)
    # create scatter of these samples
    plt.scatter(data_values[row_ix, 0], data_values[row_ix, 1])
# show the plot
plt.show()

# %% [markdown]
# #### 2.1 K-means

# %%
kmeans_model = KMeans(n_clusters=5) # set k to whatever makes sense for your data
kmeans_model.fit(data_values)
kmeans_clusters = kmeans_model.predict(data_values)

# create scatter plot for samples from each cluster
for cluster in unique(kmeans_clusters):
    # get row indexes for samples with this cluster
    row_ix = np.where(kmeans_clusters == cluster)
    # create scatter of these samples
    plt.scatter(data_values[row_ix, 0], data_values[row_ix, 1])
# show the plot
plt.show()

# %% [markdown]
# #### 2.2 DBSCAN

# %%
dbscan_model = DBSCAN(eps=0.3, min_samples=8)
dbscan_clusters = dbscan_model.fit_predict(data_values)

print(f'Found {len(unique(dbscan_clusters))} clusters')

# create scatter plot for samples from each cluster
for cluster in unique(dbscan_clusters):
    # get row indexes for samples with this cluster
    row_ix = np.where(dbscan_clusters == cluster)
    # create scatter of these samples
    plt.scatter(data_values[row_ix, 0], data_values[row_ix, 1])
# show the plot
plt.show()
# Out:
# Found 4 clusters

# %% [markdown]
# #### Some other algorithm....

# %%
# your code here
# define the model
model = AgglomerativeClustering(n_clusters=5)

# fit model and predict clusters
clusters = model.fit_predict(data_values)

# retrieve unique clusters
uniq_clusters = np.unique(clusters)
print(f'Found {len(uniq_clusters)} clusters')

# create scatter plot for samples from each cluster
for cluster in uniq_clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(clusters == cluster)
    # create scatter of these samples
    plt.scatter(data_values[row_ix, 0], data_values[row_ix, 1])

plt.show()
# Out:
# Found 5 clusters
